# %%
import numpy as np
import pandas as pd
import logging

# %%
# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

data = {
    'index': np.arange(1, 201),
    'amount': np.random.randint(1, 100, size=200)  
}
df = pd.DataFrame(data)

target_sum = 23

def find_combinations(df, target_sum):
    result = []

    def backtrack(start, current_sum, current_indices):
        try:
            if current_sum == target_sum:
                result.append(current_indices[:])
                logging.info(f"Found combination: {current_indices}")
                return
            if current_sum > target_sum:
                return
            
            for i in range(start, len(df)):
                current_indices.append(df['index'][i])
                backtrack(i + 1, current_sum + df['amount'][i], current_indices)
                current_indices.pop()
        except Exception as e:
            logging.error(f"Error occurred: {e}")
    
    backtrack(0, 0, [])
    return result
try:
    combinations = find_combinations(df, target_sum)
    df_new = []
    if combinations:
        for combination in combinations:
            print(f"Indices that sum to {target_sum}: {combination}")
            matching_rows = df[df['index'].isin(combination)]
            df_new.append(matching_rows)
            print(matching_rows)
    else:
        raise ValueError("No combinations match the target sum.")
except ValueError as ve:
    logging.info(f"No combinations found that sum to {target_sum}.")
# Out:
# 2024-08-22 23:33:00,382 - INFO - Found combination: [np.int64(2), np.int64(9), np.int64(35), np.int64(91)]
# 2024-08-22 23:33:00,384 - INFO - Found combination: [np.int64(2), np.int64(9), np.int64(48)]
# 2024-08-22 23:33:00,385 - INFO - Found combination: [np.int64(2), np.int64(9), np.int64(91), np.int64(93), np.int64(125)]
# 2024-08-22 23:33:00,386 - INFO - Found combination: [np.int64(2), np.int64(9), np.int64(91), np.int64(94)]
# 2024-08-22 23:33:00,387 - INFO - Found combination: [np.int64(2), np.int64(9), np.int64(91), np.int64(118), np.int64(125)]
# 2024-08-22 23:33:00,388 - INFO - Found combination: [np.int64(2), np.int64(9), np.int64(91), np.int64(125), np.int64(156)]
# 2024-08-22 23:33:00,390 - INFO - Found combination: [np.int64(2), np.int64(9), np.int64(93), np.int64(118), np.int64(156)]
# 2024-08-22 23:33:00,392 - INFO - Found combination: [np.int64(2), np.int64(9), np.int64(93), np.int64(137)]
# 2024-08-22 23:33:00,393 - INFO - Found combination: [np.int64(2), np.int64(9), np.int64(93), np.int64(184)]
# 2024-08-22 23:33:00,396 - INFO - Found combination: [np.int64(2), np.int64(9), np.int64(118), np.int64(137)]
# 2024-08-22 23:33:00,398 - INFO - Found combination: [np.int64(2), np.int64(9), np.int64(118), np.int64(184)]
# 2024-08-22 23:33:00,400 - INFO - Found combination: [np.int64(2), np.int64(9), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,402 - INFO - Found combination: [np.int64(2), np.int64(9), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,405 - INFO - Found combination: [np.int64(2), np.int64(35), np.int64(93)]
# 2024-08-22 23:33:00,406 - INFO - Found combination: [np.int64(2), np.int64(35), np.int64(118)]
# 2024-08-22 23:33:00,407 - INFO - Found combination: [np.int64(2), np.int64(35), np.int64(156)]
# 2024-08-22 23:33:00,407 - INFO - Found combination: [np.int64(2), np.int64(48), np.int64(91)]
# 2024-08-22 23:33:00,409 - INFO - Found combination: [np.int64(2), np.int64(91), np.int64(93), np.int64(118), np.int64(156)]
# 2024-08-22 23:33:00,410 - INFO - Found combination: [np.int64(2), np.int64(91), np.int64(93), np.int64(137)]
# 2024-08-22 23:33:00,411 - INFO - Found combination: [np.int64(2), np.int64(91), np.int64(93), np.int64(184)]
# 2024-08-22 23:33:00,414 - INFO - Found combination: [np.int64(2), np.int64(91), np.int64(118), np.int64(137)]
# 2024-08-22 23:33:00,417 - INFO - Found combination: [np.int64(2), np.int64(91), np.int64(118), np.int64(184)]
# 2024-08-22 23:33:00,419 - INFO - Found combination: [np.int64(2), np.int64(91), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,420 - INFO - Found combination: [np.int64(2), np.int64(91), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,421 - INFO - Found combination: [np.int64(2), np.int64(93), np.int64(94)]
# 2024-08-22 23:33:00,421 - INFO - Found combination: [np.int64(2), np.int64(93), np.int64(118), np.int64(125)]
# 2024-08-22 23:33:00,422 - INFO - Found combination: [np.int64(2), np.int64(93), np.int64(125), np.int64(156)]
# 2024-08-22 23:33:00,424 - INFO - Found combination: [np.int64(2), np.int64(94), np.int64(118)]
# 2024-08-22 23:33:00,425 - INFO - Found combination: [np.int64(2), np.int64(94), np.int64(156)]
# 2024-08-22 23:33:00,426 - INFO - Found combination: [np.int64(2), np.int64(118), np.int64(125), np.int64(156)]
# 2024-08-22 23:33:00,428 - INFO - Found combination: [np.int64(2), np.int64(125), np.int64(137)]
# 2024-08-22 23:33:00,429 - INFO - Found combination: [np.int64(2), np.int64(125), np.int64(184)]
# 2024-08-22 23:33:00,430 - INFO - Found combination: [np.int64(2), np.int64(151)]
# 2024-08-22 23:33:00,431 - INFO - Found combination: [np.int64(2), np.int64(171)]
# 2024-08-22 23:33:00,432 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(27), np.int64(91)]
# 2024-08-22 23:33:00,434 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(35), np.int64(48), np.int64(91)]
# 2024-08-22 23:33:00,435 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(35), np.int64(91), np.int64(93), np.int64(118), np.int64(156)]
# 2024-08-22 23:33:00,436 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(35), np.int64(91), np.int64(93), np.int64(137)]
# 2024-08-22 23:33:00,438 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(35), np.int64(91), np.int64(93), np.int64(184)]
# 2024-08-22 23:33:00,440 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(35), np.int64(91), np.int64(118), np.int64(137)]
# 2024-08-22 23:33:00,441 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(35), np.int64(91), np.int64(118), np.int64(184)]
# 2024-08-22 23:33:00,443 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(35), np.int64(91), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,444 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(35), np.int64(91), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,445 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(35), np.int64(93), np.int64(94)]
# 2024-08-22 23:33:00,447 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(35), np.int64(93), np.int64(118), np.int64(125)]
# 2024-08-22 23:33:00,448 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(35), np.int64(93), np.int64(125), np.int64(156)]
# 2024-08-22 23:33:00,450 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(35), np.int64(94), np.int64(118)]
# 2024-08-22 23:33:00,450 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(35), np.int64(94), np.int64(156)]
# 2024-08-22 23:33:00,451 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(35), np.int64(118), np.int64(125), np.int64(156)]
# 2024-08-22 23:33:00,453 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(35), np.int64(125), np.int64(137)]
# 2024-08-22 23:33:00,454 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(35), np.int64(125), np.int64(184)]
# 2024-08-22 23:33:00,456 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(35), np.int64(151)]
# 2024-08-22 23:33:00,457 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(35), np.int64(171)]
# 2024-08-22 23:33:00,458 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(48), np.int64(91), np.int64(93), np.int64(125)]
# 2024-08-22 23:33:00,459 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(48), np.int64(91), np.int64(94)]
# 2024-08-22 23:33:00,460 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(48), np.int64(91), np.int64(118), np.int64(125)]
# 2024-08-22 23:33:00,461 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(48), np.int64(91), np.int64(125), np.int64(156)]
# 2024-08-22 23:33:00,463 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(48), np.int64(93), np.int64(118), np.int64(156)]
# 2024-08-22 23:33:00,468 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(48), np.int64(93), np.int64(137)]
# 2024-08-22 23:33:00,469 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(48), np.int64(93), np.int64(184)]
# 2024-08-22 23:33:00,471 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(48), np.int64(118), np.int64(137)]
# 2024-08-22 23:33:00,472 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(48), np.int64(118), np.int64(184)]
# 2024-08-22 23:33:00,473 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(48), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,475 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(48), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,477 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(64), np.int64(93)]
# 2024-08-22 23:33:00,477 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(64), np.int64(118)]
# 2024-08-22 23:33:00,478 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(64), np.int64(156)]
# 2024-08-22 23:33:00,479 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(93), np.int64(94), np.int64(118), np.int64(156)]
# 2024-08-22 23:33:00,480 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(93), np.int64(94), np.int64(137)]
# 2024-08-22 23:33:00,482 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(93), np.int64(94), np.int64(184)]
# 2024-08-22 23:33:00,483 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(93), np.int64(110)]
# 2024-08-22 23:33:00,483 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(93), np.int64(118), np.int64(125), np.int64(137)]
# 2024-08-22 23:33:00,484 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(93), np.int64(118), np.int64(125), np.int64(184)]
# 2024-08-22 23:33:00,485 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(93), np.int64(118), np.int64(151)]
# 2024-08-22 23:33:00,487 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(93), np.int64(118), np.int64(171)]
# 2024-08-22 23:33:00,488 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(93), np.int64(125), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,489 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(93), np.int64(125), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,492 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(93), np.int64(126)]
# 2024-08-22 23:33:00,494 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(93), np.int64(151), np.int64(156)]
# 2024-08-22 23:33:00,496 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(93), np.int64(156), np.int64(171)]
# 2024-08-22 23:33:00,498 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(93), np.int64(199)]
# 2024-08-22 23:33:00,499 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(94), np.int64(118), np.int64(137)]
# 2024-08-22 23:33:00,500 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(94), np.int64(118), np.int64(184)]
# 2024-08-22 23:33:00,502 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(94), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,503 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(94), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,504 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(110), np.int64(118)]
# 2024-08-22 23:33:00,505 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(110), np.int64(156)]
# 2024-08-22 23:33:00,506 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(118), np.int64(125), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,507 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(118), np.int64(125), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,508 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(118), np.int64(126)]
# 2024-08-22 23:33:00,509 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(118), np.int64(151), np.int64(156)]
# 2024-08-22 23:33:00,509 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(118), np.int64(156), np.int64(171)]
# 2024-08-22 23:33:00,511 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(118), np.int64(199)]
# 2024-08-22 23:33:00,513 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(125), np.int64(137), np.int64(184)]
# 2024-08-22 23:33:00,515 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(125), np.int64(159)]
# 2024-08-22 23:33:00,516 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(126), np.int64(156)]
# 2024-08-22 23:33:00,518 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(137), np.int64(151)]
# 2024-08-22 23:33:00,519 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(137), np.int64(171)]
# 2024-08-22 23:33:00,520 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(146)]
# 2024-08-22 23:33:00,521 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(151), np.int64(184)]
# 2024-08-22 23:33:00,522 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(156), np.int64(199)]
# 2024-08-22 23:33:00,523 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(91), np.int64(171), np.int64(184)]
# 2024-08-22 23:33:00,525 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(93), np.int64(94), np.int64(118), np.int64(125)]
# 2024-08-22 23:33:00,526 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(93), np.int64(94), np.int64(125), np.int64(156)]
# 2024-08-22 23:33:00,530 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(93), np.int64(118), np.int64(137), np.int64(184)]
# 2024-08-22 23:33:00,531 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(93), np.int64(118), np.int64(159)]
# 2024-08-22 23:33:00,533 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(93), np.int64(125), np.int64(151)]
# 2024-08-22 23:33:00,534 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(93), np.int64(125), np.int64(171)]
# 2024-08-22 23:33:00,536 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(93), np.int64(136)]
# 2024-08-22 23:33:00,536 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(93), np.int64(137), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,538 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(93), np.int64(156), np.int64(159)]
# 2024-08-22 23:33:00,540 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(94), np.int64(118), np.int64(125), np.int64(156)]
# 2024-08-22 23:33:00,543 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(94), np.int64(125), np.int64(137)]
# 2024-08-22 23:33:00,544 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(94), np.int64(125), np.int64(184)]
# 2024-08-22 23:33:00,546 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(94), np.int64(151)]
# 2024-08-22 23:33:00,547 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(94), np.int64(171)]
# 2024-08-22 23:33:00,548 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(110), np.int64(125)]
# 2024-08-22 23:33:00,550 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(118), np.int64(125), np.int64(151)]
# 2024-08-22 23:33:00,552 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(118), np.int64(125), np.int64(171)]
# 2024-08-22 23:33:00,554 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(118), np.int64(136)]
# 2024-08-22 23:33:00,554 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(118), np.int64(137), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,555 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(118), np.int64(156), np.int64(159)]
# 2024-08-22 23:33:00,557 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(125), np.int64(126)]
# 2024-08-22 23:33:00,558 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(125), np.int64(151), np.int64(156)]
# 2024-08-22 23:33:00,559 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(125), np.int64(156), np.int64(171)]
# 2024-08-22 23:33:00,560 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(125), np.int64(199)]
# 2024-08-22 23:33:00,561 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(129)]
# 2024-08-22 23:33:00,562 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(136), np.int64(156)]
# 2024-08-22 23:33:00,563 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(137), np.int64(159)]
# 2024-08-22 23:33:00,566 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(159), np.int64(184)]
# 2024-08-22 23:33:00,567 - INFO - Found combination: [np.int64(8), np.int64(9), np.int64(196)]
# 2024-08-22 23:33:00,569 - INFO - Found combination: [np.int64(8), np.int64(27), np.int64(93)]
# 2024-08-22 23:33:00,570 - INFO - Found combination: [np.int64(8), np.int64(27), np.int64(118)]
# 2024-08-22 23:33:00,570 - INFO - Found combination: [np.int64(8), np.int64(27), np.int64(156)]
# 2024-08-22 23:33:00,572 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(48), np.int64(93)]
# 2024-08-22 23:33:00,573 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(48), np.int64(118)]
# 2024-08-22 23:33:00,574 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(48), np.int64(156)]
# 2024-08-22 23:33:00,575 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(91), np.int64(93), np.int64(94)]
# 2024-08-22 23:33:00,575 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(91), np.int64(93), np.int64(118), np.int64(125)]
# 2024-08-22 23:33:00,577 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(91), np.int64(93), np.int64(125), np.int64(156)]
# 2024-08-22 23:33:00,579 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(91), np.int64(94), np.int64(118)]
# 2024-08-22 23:33:00,579 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(91), np.int64(94), np.int64(156)]
# 2024-08-22 23:33:00,580 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(91), np.int64(118), np.int64(125), np.int64(156)]
# 2024-08-22 23:33:00,582 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(91), np.int64(125), np.int64(137)]
# 2024-08-22 23:33:00,583 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(91), np.int64(125), np.int64(184)]
# 2024-08-22 23:33:00,585 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(91), np.int64(151)]
# 2024-08-22 23:33:00,586 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(91), np.int64(171)]
# 2024-08-22 23:33:00,588 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(93), np.int64(118), np.int64(137)]
# 2024-08-22 23:33:00,589 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(93), np.int64(118), np.int64(184)]
# 2024-08-22 23:33:00,590 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(93), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,593 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(93), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,594 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(94), np.int64(125)]
# 2024-08-22 23:33:00,596 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(118), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,597 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(118), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,600 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(137), np.int64(184)]
# 2024-08-22 23:33:00,602 - INFO - Found combination: [np.int64(8), np.int64(35), np.int64(159)]
# 2024-08-22 23:33:00,603 - INFO - Found combination: [np.int64(8), np.int64(43)]
# 2024-08-22 23:33:00,604 - INFO - Found combination: [np.int64(8), np.int64(48), np.int64(91), np.int64(93), np.int64(118), np.int64(156)]
# 2024-08-22 23:33:00,605 - INFO - Found combination: [np.int64(8), np.int64(48), np.int64(91), np.int64(93), np.int64(137)]
# 2024-08-22 23:33:00,606 - INFO - Found combination: [np.int64(8), np.int64(48), np.int64(91), np.int64(93), np.int64(184)]
# 2024-08-22 23:33:00,608 - INFO - Found combination: [np.int64(8), np.int64(48), np.int64(91), np.int64(118), np.int64(137)]
# 2024-08-22 23:33:00,609 - INFO - Found combination: [np.int64(8), np.int64(48), np.int64(91), np.int64(118), np.int64(184)]
# 2024-08-22 23:33:00,610 - INFO - Found combination: [np.int64(8), np.int64(48), np.int64(91), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,611 - INFO - Found combination: [np.int64(8), np.int64(48), np.int64(91), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,611 - INFO - Found combination: [np.int64(8), np.int64(48), np.int64(93), np.int64(94)]
# 2024-08-22 23:33:00,612 - INFO - Found combination: [np.int64(8), np.int64(48), np.int64(93), np.int64(118), np.int64(125)]
# 2024-08-22 23:33:00,613 - INFO - Found combination: [np.int64(8), np.int64(48), np.int64(93), np.int64(125), np.int64(156)]
# 2024-08-22 23:33:00,616 - INFO - Found combination: [np.int64(8), np.int64(48), np.int64(94), np.int64(118)]
# 2024-08-22 23:33:00,617 - INFO - Found combination: [np.int64(8), np.int64(48), np.int64(94), np.int64(156)]
# 2024-08-22 23:33:00,618 - INFO - Found combination: [np.int64(8), np.int64(48), np.int64(118), np.int64(125), np.int64(156)]
# 2024-08-22 23:33:00,620 - INFO - Found combination: [np.int64(8), np.int64(48), np.int64(125), np.int64(137)]
# 2024-08-22 23:33:00,621 - INFO - Found combination: [np.int64(8), np.int64(48), np.int64(125), np.int64(184)]
# 2024-08-22 23:33:00,622 - INFO - Found combination: [np.int64(8), np.int64(48), np.int64(151)]
# 2024-08-22 23:33:00,623 - INFO - Found combination: [np.int64(8), np.int64(48), np.int64(171)]
# 2024-08-22 23:33:00,624 - INFO - Found combination: [np.int64(8), np.int64(64), np.int64(91), np.int64(93)]
# 2024-08-22 23:33:00,625 - INFO - Found combination: [np.int64(8), np.int64(64), np.int64(91), np.int64(118)]
# 2024-08-22 23:33:00,625 - INFO - Found combination: [np.int64(8), np.int64(64), np.int64(91), np.int64(156)]
# 2024-08-22 23:33:00,627 - INFO - Found combination: [np.int64(8), np.int64(64), np.int64(125)]
# 2024-08-22 23:33:00,630 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(93), np.int64(94), np.int64(118), np.int64(125)]
# 2024-08-22 23:33:00,631 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(93), np.int64(94), np.int64(125), np.int64(156)]
# 2024-08-22 23:33:00,636 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(93), np.int64(118), np.int64(137), np.int64(184)]
# 2024-08-22 23:33:00,638 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(93), np.int64(118), np.int64(159)]
# 2024-08-22 23:33:00,640 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(93), np.int64(125), np.int64(151)]
# 2024-08-22 23:33:00,641 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(93), np.int64(125), np.int64(171)]
# 2024-08-22 23:33:00,643 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(93), np.int64(136)]
# 2024-08-22 23:33:00,643 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(93), np.int64(137), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,645 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(93), np.int64(156), np.int64(159)]
# 2024-08-22 23:33:00,647 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(94), np.int64(118), np.int64(125), np.int64(156)]
# 2024-08-22 23:33:00,648 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(94), np.int64(125), np.int64(137)]
# 2024-08-22 23:33:00,650 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(94), np.int64(125), np.int64(184)]
# 2024-08-22 23:33:00,651 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(94), np.int64(151)]
# 2024-08-22 23:33:00,653 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(94), np.int64(171)]
# 2024-08-22 23:33:00,654 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(110), np.int64(125)]
# 2024-08-22 23:33:00,656 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(118), np.int64(125), np.int64(151)]
# 2024-08-22 23:33:00,657 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(118), np.int64(125), np.int64(171)]
# 2024-08-22 23:33:00,658 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(118), np.int64(136)]
# 2024-08-22 23:33:00,658 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(118), np.int64(137), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,660 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(118), np.int64(156), np.int64(159)]
# 2024-08-22 23:33:00,661 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(125), np.int64(126)]
# 2024-08-22 23:33:00,662 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(125), np.int64(151), np.int64(156)]
# 2024-08-22 23:33:00,663 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(125), np.int64(156), np.int64(171)]
# 2024-08-22 23:33:00,665 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(125), np.int64(199)]
# 2024-08-22 23:33:00,666 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(129)]
# 2024-08-22 23:33:00,667 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(136), np.int64(156)]
# 2024-08-22 23:33:00,668 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(137), np.int64(159)]
# 2024-08-22 23:33:00,671 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(159), np.int64(184)]
# 2024-08-22 23:33:00,672 - INFO - Found combination: [np.int64(8), np.int64(91), np.int64(196)]
# 2024-08-22 23:33:00,673 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(94), np.int64(118), np.int64(137)]
# 2024-08-22 23:33:00,675 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(94), np.int64(118), np.int64(184)]
# 2024-08-22 23:33:00,676 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(94), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,677 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(94), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,678 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(110), np.int64(118)]
# 2024-08-22 23:33:00,679 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(110), np.int64(156)]
# 2024-08-22 23:33:00,679 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(118), np.int64(125), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,681 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(118), np.int64(125), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,682 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(118), np.int64(126)]
# 2024-08-22 23:33:00,683 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(118), np.int64(151), np.int64(156)]
# 2024-08-22 23:33:00,684 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(118), np.int64(156), np.int64(171)]
# 2024-08-22 23:33:00,686 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(118), np.int64(199)]
# 2024-08-22 23:33:00,687 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(125), np.int64(137), np.int64(184)]
# 2024-08-22 23:33:00,688 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(125), np.int64(159)]
# 2024-08-22 23:33:00,690 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(126), np.int64(156)]
# 2024-08-22 23:33:00,691 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(137), np.int64(151)]
# 2024-08-22 23:33:00,692 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(137), np.int64(171)]
# 2024-08-22 23:33:00,692 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(146)]
# 2024-08-22 23:33:00,693 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(151), np.int64(184)]
# 2024-08-22 23:33:00,695 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(156), np.int64(199)]
# 2024-08-22 23:33:00,695 - INFO - Found combination: [np.int64(8), np.int64(93), np.int64(171), np.int64(184)]
# 2024-08-22 23:33:00,697 - INFO - Found combination: [np.int64(8), np.int64(94), np.int64(118), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,698 - INFO - Found combination: [np.int64(8), np.int64(94), np.int64(118), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,700 - INFO - Found combination: [np.int64(8), np.int64(94), np.int64(137), np.int64(184)]
# 2024-08-22 23:33:00,702 - INFO - Found combination: [np.int64(8), np.int64(94), np.int64(159)]
# 2024-08-22 23:33:00,703 - INFO - Found combination: [np.int64(8), np.int64(110), np.int64(118), np.int64(156)]
# 2024-08-22 23:33:00,705 - INFO - Found combination: [np.int64(8), np.int64(110), np.int64(137)]
# 2024-08-22 23:33:00,706 - INFO - Found combination: [np.int64(8), np.int64(110), np.int64(184)]
# 2024-08-22 23:33:00,707 - INFO - Found combination: [np.int64(8), np.int64(118), np.int64(125), np.int64(137), np.int64(184)]
# 2024-08-22 23:33:00,708 - INFO - Found combination: [np.int64(8), np.int64(118), np.int64(125), np.int64(159)]
# 2024-08-22 23:33:00,710 - INFO - Found combination: [np.int64(8), np.int64(118), np.int64(126), np.int64(156)]
# 2024-08-22 23:33:00,711 - INFO - Found combination: [np.int64(8), np.int64(118), np.int64(137), np.int64(151)]
# 2024-08-22 23:33:00,712 - INFO - Found combination: [np.int64(8), np.int64(118), np.int64(137), np.int64(171)]
# 2024-08-22 23:33:00,712 - INFO - Found combination: [np.int64(8), np.int64(118), np.int64(146)]
# 2024-08-22 23:33:00,714 - INFO - Found combination: [np.int64(8), np.int64(118), np.int64(151), np.int64(184)]
# 2024-08-22 23:33:00,715 - INFO - Found combination: [np.int64(8), np.int64(118), np.int64(156), np.int64(199)]
# 2024-08-22 23:33:00,716 - INFO - Found combination: [np.int64(8), np.int64(118), np.int64(171), np.int64(184)]
# 2024-08-22 23:33:00,718 - INFO - Found combination: [np.int64(8), np.int64(125), np.int64(136)]
# 2024-08-22 23:33:00,719 - INFO - Found combination: [np.int64(8), np.int64(125), np.int64(137), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,721 - INFO - Found combination: [np.int64(8), np.int64(125), np.int64(156), np.int64(159)]
# 2024-08-22 23:33:00,723 - INFO - Found combination: [np.int64(8), np.int64(126), np.int64(137)]
# 2024-08-22 23:33:00,725 - INFO - Found combination: [np.int64(8), np.int64(126), np.int64(184)]
# 2024-08-22 23:33:00,726 - INFO - Found combination: [np.int64(8), np.int64(137), np.int64(151), np.int64(156)]
# 2024-08-22 23:33:00,727 - INFO - Found combination: [np.int64(8), np.int64(137), np.int64(156), np.int64(171)]
# 2024-08-22 23:33:00,729 - INFO - Found combination: [np.int64(8), np.int64(137), np.int64(199)]
# 2024-08-22 23:33:00,729 - INFO - Found combination: [np.int64(8), np.int64(146), np.int64(156)]
# 2024-08-22 23:33:00,730 - INFO - Found combination: [np.int64(8), np.int64(151), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,731 - INFO - Found combination: [np.int64(8), np.int64(155)]
# 2024-08-22 23:33:00,734 - INFO - Found combination: [np.int64(8), np.int64(156), np.int64(171), np.int64(184)]
# 2024-08-22 23:33:00,735 - INFO - Found combination: [np.int64(8), np.int64(157)]
# 2024-08-22 23:33:00,737 - INFO - Found combination: [np.int64(8), np.int64(184), np.int64(199)]
# 2024-08-22 23:33:00,738 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(35), np.int64(48)]
# 2024-08-22 23:33:00,739 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(35), np.int64(91), np.int64(93), np.int64(125)]
# 2024-08-22 23:33:00,741 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(35), np.int64(91), np.int64(94)]
# 2024-08-22 23:33:00,741 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(35), np.int64(91), np.int64(118), np.int64(125)]
# 2024-08-22 23:33:00,743 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(35), np.int64(91), np.int64(125), np.int64(156)]
# 2024-08-22 23:33:00,744 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(35), np.int64(93), np.int64(118), np.int64(156)]
# 2024-08-22 23:33:00,746 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(35), np.int64(93), np.int64(137)]
# 2024-08-22 23:33:00,747 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(35), np.int64(93), np.int64(184)]
# 2024-08-22 23:33:00,748 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(35), np.int64(118), np.int64(137)]
# 2024-08-22 23:33:00,750 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(35), np.int64(118), np.int64(184)]
# 2024-08-22 23:33:00,751 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(35), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,753 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(35), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,755 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(48), np.int64(91), np.int64(93), np.int64(118)]
# 2024-08-22 23:33:00,755 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(48), np.int64(91), np.int64(93), np.int64(156)]
# 2024-08-22 23:33:00,756 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(48), np.int64(91), np.int64(118), np.int64(156)]
# 2024-08-22 23:33:00,757 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(48), np.int64(91), np.int64(137)]
# 2024-08-22 23:33:00,758 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(48), np.int64(91), np.int64(184)]
# 2024-08-22 23:33:00,759 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(48), np.int64(93), np.int64(125)]
# 2024-08-22 23:33:00,760 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(48), np.int64(94)]
# 2024-08-22 23:33:00,761 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(48), np.int64(118), np.int64(125)]
# 2024-08-22 23:33:00,762 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(48), np.int64(125), np.int64(156)]
# 2024-08-22 23:33:00,764 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(64), np.int64(91)]
# 2024-08-22 23:33:00,766 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(91), np.int64(93), np.int64(94), np.int64(125)]
# 2024-08-22 23:33:00,769 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(91), np.int64(93), np.int64(118), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,771 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(91), np.int64(93), np.int64(118), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,773 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(91), np.int64(93), np.int64(137), np.int64(184)]
# 2024-08-22 23:33:00,774 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(91), np.int64(93), np.int64(159)]
# 2024-08-22 23:33:00,775 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(91), np.int64(94), np.int64(118), np.int64(125)]
# 2024-08-22 23:33:00,778 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(91), np.int64(94), np.int64(125), np.int64(156)]
# 2024-08-22 23:33:00,782 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(91), np.int64(118), np.int64(137), np.int64(184)]
# 2024-08-22 23:33:00,783 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(91), np.int64(118), np.int64(159)]
# 2024-08-22 23:33:00,785 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(91), np.int64(125), np.int64(151)]
# 2024-08-22 23:33:00,787 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(91), np.int64(125), np.int64(171)]
# 2024-08-22 23:33:00,788 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(91), np.int64(136)]
# 2024-08-22 23:33:00,790 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(91), np.int64(137), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,792 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(91), np.int64(156), np.int64(159)]
# 2024-08-22 23:33:00,794 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(93), np.int64(94), np.int64(118), np.int64(156)]
# 2024-08-22 23:33:00,795 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(93), np.int64(94), np.int64(137)]
# 2024-08-22 23:33:00,796 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(93), np.int64(94), np.int64(184)]
# 2024-08-22 23:33:00,796 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(93), np.int64(110)]
# 2024-08-22 23:33:00,797 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(93), np.int64(118), np.int64(125), np.int64(137)]
# 2024-08-22 23:33:00,798 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(93), np.int64(118), np.int64(125), np.int64(184)]
# 2024-08-22 23:33:00,799 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(93), np.int64(118), np.int64(151)]
# 2024-08-22 23:33:00,800 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(93), np.int64(118), np.int64(171)]
# 2024-08-22 23:33:00,801 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(93), np.int64(125), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,802 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(93), np.int64(125), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,803 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(93), np.int64(126)]
# 2024-08-22 23:33:00,805 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(93), np.int64(151), np.int64(156)]
# 2024-08-22 23:33:00,805 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(93), np.int64(156), np.int64(171)]
# 2024-08-22 23:33:00,807 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(93), np.int64(199)]
# 2024-08-22 23:33:00,808 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(94), np.int64(118), np.int64(137)]
# 2024-08-22 23:33:00,809 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(94), np.int64(118), np.int64(184)]
# 2024-08-22 23:33:00,810 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(94), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,811 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(94), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,811 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(110), np.int64(118)]
# 2024-08-22 23:33:00,812 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(110), np.int64(156)]
# 2024-08-22 23:33:00,813 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(118), np.int64(125), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,814 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(118), np.int64(125), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,814 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(118), np.int64(126)]
# 2024-08-22 23:33:00,816 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(118), np.int64(151), np.int64(156)]
# 2024-08-22 23:33:00,817 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(118), np.int64(156), np.int64(171)]
# 2024-08-22 23:33:00,819 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(118), np.int64(199)]
# 2024-08-22 23:33:00,821 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(125), np.int64(137), np.int64(184)]
# 2024-08-22 23:33:00,822 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(125), np.int64(159)]
# 2024-08-22 23:33:00,823 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(126), np.int64(156)]
# 2024-08-22 23:33:00,824 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(137), np.int64(151)]
# 2024-08-22 23:33:00,824 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(137), np.int64(171)]
# 2024-08-22 23:33:00,825 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(146)]
# 2024-08-22 23:33:00,826 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(151), np.int64(184)]
# 2024-08-22 23:33:00,827 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(156), np.int64(199)]
# 2024-08-22 23:33:00,828 - INFO - Found combination: [np.int64(9), np.int64(27), np.int64(171), np.int64(184)]
# 2024-08-22 23:33:00,829 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(36), np.int64(91)]
# 2024-08-22 23:33:00,831 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(43), np.int64(91), np.int64(125)]
# 2024-08-22 23:33:00,833 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(43), np.int64(93), np.int64(118)]
# 2024-08-22 23:33:00,834 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(43), np.int64(93), np.int64(156)]
# 2024-08-22 23:33:00,835 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(43), np.int64(118), np.int64(156)]
# 2024-08-22 23:33:00,836 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(43), np.int64(137)]
# 2024-08-22 23:33:00,837 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(43), np.int64(184)]
# 2024-08-22 23:33:00,838 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(64), np.int64(91)]
# 2024-08-22 23:33:00,840 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(91), np.int64(93), np.int64(94), np.int64(125)]
# 2024-08-22 23:33:00,842 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(91), np.int64(93), np.int64(118), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,843 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(91), np.int64(93), np.int64(118), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,845 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(91), np.int64(93), np.int64(137), np.int64(184)]
# 2024-08-22 23:33:00,847 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(91), np.int64(93), np.int64(159)]
# 2024-08-22 23:33:00,848 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(91), np.int64(94), np.int64(118), np.int64(125)]
# 2024-08-22 23:33:00,849 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(91), np.int64(94), np.int64(125), np.int64(156)]
# 2024-08-22 23:33:00,853 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(91), np.int64(118), np.int64(137), np.int64(184)]
# 2024-08-22 23:33:00,854 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(91), np.int64(118), np.int64(159)]
# 2024-08-22 23:33:00,856 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(91), np.int64(125), np.int64(151)]
# 2024-08-22 23:33:00,857 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(91), np.int64(125), np.int64(171)]
# 2024-08-22 23:33:00,858 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(91), np.int64(136)]
# 2024-08-22 23:33:00,859 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(91), np.int64(137), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,860 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(91), np.int64(156), np.int64(159)]
# 2024-08-22 23:33:00,862 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(93), np.int64(94), np.int64(118), np.int64(156)]
# 2024-08-22 23:33:00,863 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(93), np.int64(94), np.int64(137)]
# 2024-08-22 23:33:00,864 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(93), np.int64(94), np.int64(184)]
# 2024-08-22 23:33:00,865 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(93), np.int64(110)]
# 2024-08-22 23:33:00,865 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(93), np.int64(118), np.int64(125), np.int64(137)]
# 2024-08-22 23:33:00,866 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(93), np.int64(118), np.int64(125), np.int64(184)]
# 2024-08-22 23:33:00,867 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(93), np.int64(118), np.int64(151)]
# 2024-08-22 23:33:00,869 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(93), np.int64(118), np.int64(171)]
# 2024-08-22 23:33:00,871 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(93), np.int64(125), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,872 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(93), np.int64(125), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,873 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(93), np.int64(126)]
# 2024-08-22 23:33:00,874 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(93), np.int64(151), np.int64(156)]
# 2024-08-22 23:33:00,875 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(93), np.int64(156), np.int64(171)]
# 2024-08-22 23:33:00,877 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(93), np.int64(199)]
# 2024-08-22 23:33:00,878 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(94), np.int64(118), np.int64(137)]
# 2024-08-22 23:33:00,879 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(94), np.int64(118), np.int64(184)]
# 2024-08-22 23:33:00,880 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(94), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,881 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(94), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,882 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(110), np.int64(118)]
# 2024-08-22 23:33:00,882 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(110), np.int64(156)]
# 2024-08-22 23:33:00,883 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(118), np.int64(125), np.int64(137), np.int64(156)]
# 2024-08-22 23:33:00,884 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(118), np.int64(125), np.int64(156), np.int64(184)]
# 2024-08-22 23:33:00,886 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(118), np.int64(126)]
# 2024-08-22 23:33:00,888 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(118), np.int64(151), np.int64(156)]
# 2024-08-22 23:33:00,889 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(118), np.int64(156), np.int64(171)]
# 2024-08-22 23:33:00,890 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(118), np.int64(199)]
# 2024-08-22 23:33:00,891 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(125), np.int64(137), np.int64(184)]
# 2024-08-22 23:33:00,893 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(125), np.int64(159)]
# 2024-08-22 23:33:00,894 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(126), np.int64(156)]
# 2024-08-22 23:33:00,896 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(137), np.int64(151)]
# 2024-08-22 23:33:00,896 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(137), np.int64(171)]
# 2024-08-22 23:33:00,897 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(146)]
# 2024-08-22 23:33:00,898 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(151), np.int64(184)]
# 2024-08-22 23:33:00,899 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(156), np.int64(199)]
# 2024-08-22 23:33:00,900 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(48), np.int64(171), np.int64(184)]
# 2024-08-22 23:33:00,901 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(52), np.int64(91)]
# 2024-08-22 23:33:00,903 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(64), np.int64(91), np.int64(93), np.int64(118), np.int64(156)]
# 2024-08-22 23:33:00,904 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(64), np.int64(91), np.int64(93), np.int64(137)]
# 2024-08-22 23:33:00,905 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(64), np.int64(91), np.int64(93), np.int64(184)]
# 2024-08-22 23:33:00,907 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(64), np.int64(91), np.int64(118), np.int64(137)]
# 2024-08-22 23:33:00,908 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(64), np.int64(91), np.int64(118), np.int64(184)]
# 2024-08-22 23:33:00,909 - INFO - Found combination: [np.int64(9), np.int64(35), np.int64(64), np.int64(91), np.int64(137), np.int64(156)]
# ...
#      index  amount
# 117    118       2
# 136    137       4
# 158    159       8
# 198    199       9
# Indices that sum to 23: [np.int64(118), np.int64(137), np.int64(162)]
#      index  amount
# 117    118       2
# 136    137       4
# 161    162      17
# Indices that sum to 23: [np.int64(118), np.int64(137), np.int64(180)]
#      index  amount
# 117    118       2
# 136    137       4
# 179    180      17
# Indices that sum to 23: [np.int64(118), np.int64(139), np.int64(184)]
#      index  amount
# 117    118       2
# 138    139      17
# 183    184       4
# Indices that sum to 23: [np.int64(118), np.int64(146), np.int64(156), np.int64(159)]
#      index  amount
# 117    118       2
# 145    146      11
# 155    156       2
# 158    159       8
# Indices that sum to 23: [np.int64(118), np.int64(151), np.int64(156), np.int64(159), np.int64(184)]
#      index  amount
# 117    118       2
# 150    151       7
# 155    156       2
# 158    159       8
# 183    184       4
# Indices that sum to 23: [np.int64(118), np.int64(151), np.int64(156), np.int64(196)]
#      index  amount
# 117    118       2
# 150    151       7
# 155    156       2
# 195    196      12
# Indices that sum to 23: [np.int64(118), np.int64(151), np.int64(176)]
#      index  amount
# 117    118       2
# 150    151       7
# 175    176      14
# Indices that sum to 23: [np.int64(118), np.int64(155), np.int64(159)]
#      index  amount
# 117    118       2
# 154    155      13
# 158    159       8
# Indices that sum to 23: [np.int64(118), np.int64(156), np.int64(159), np.int64(171), np.int64(184)]
#      index  amount
# 117    118       2
# 155    156       2
# 158    159       8
# 170    171       7
# 183    184       4
# Indices that sum to 23: [np.int64(118), np.int64(156), np.int64(171), np.int64(196)]
#      index  amount
# 117    118       2
# 155    156       2
# 170    171       7
# 195    196      12
# Indices that sum to 23: [np.int64(118), np.int64(157), np.int64(159)]
#      index  amount
# 117    118       2
# 156    157      13
# 158    159       8
# Indices that sum to 23: [np.int64(118), np.int64(159), np.int64(184), np.int64(199)]
#      index  amount
# 117    118       2
# 158    159       8
# 183    184       4
# 198    199       9
# Indices that sum to 23: [np.int64(118), np.int64(162), np.int64(184)]
#      index  amount
# 117    118       2
# 161    162      17
# 183    184       4
# Indices that sum to 23: [np.int64(118), np.int64(171), np.int64(176)]
#      index  amount
# 117    118       2
# 170    171       7
# 175    176      14
# Indices that sum to 23: [np.int64(118), np.int64(180), np.int64(184)]
#      index  amount
# 117    118       2
# 179    180      17
# 183    184       4
# Indices that sum to 23: [np.int64(118), np.int64(189)]
#      index  amount
# 117    118       2
# 188    189      21
# Indices that sum to 23: [np.int64(118), np.int64(196), np.int64(199)]
#      index  amount
# 117    118       2
# 195    196      12
# 198    199       9
# Indices that sum to 23: [np.int64(125), np.int64(126), np.int64(137), np.int64(151)]
#      index  amount
# 124    125       3
# 125    126       9
# 136    137       4
# 150    151       7
# Indices that sum to 23: [np.int64(125), np.int64(126), np.int64(137), np.int64(171)]
#      index  amount
# 124    125       3
# 125    126       9
# 136    137       4
# 170    171       7
# Indices that sum to 23: [np.int64(125), np.int64(126), np.int64(146)]
#      index  amount
# 124    125       3
# 125    126       9
# 145    146      11
# Indices that sum to 23: [np.int64(125), np.int64(126), np.int64(151), np.int64(184)]
#      index  amount
# 124    125       3
# 125    126       9
# 150    151       7
# 183    184       4
# Indices that sum to 23: [np.int64(125), np.int64(126), np.int64(156), np.int64(199)]
#      index  amount
# 124    125       3
# 125    126       9
# 155    156       2
# 198    199       9
# Indices that sum to 23: [np.int64(125), np.int64(126), np.int64(171), np.int64(184)]
#      index  amount
# 124    125       3
# 125    126       9
# 170    171       7
# 183    184       4
# Indices that sum to 23: [np.int64(125), np.int64(129), np.int64(137), np.int64(184)]
#      index  amount
# 124    125       3
# 128    129      12
# 136    137       4
# 183    184       4
# Indices that sum to 23: [np.int64(125), np.int64(129), np.int64(159)]
#      index  amount
# 124    125       3
# 128    129      12
# 158    159       8
# Indices that sum to 23: [np.int64(125), np.int64(130), np.int64(137), np.int64(156)]
#      index  amount
# 124    125       3
# 129    130      14
# 136    137       4
# 155    156       2
# Indices that sum to 23: [np.int64(125), np.int64(130), np.int64(156), np.int64(184)]
#      index  amount
# 124    125       3
# 129    130      14
# 155    156       2
# 183    184       4
# Indices that sum to 23: [np.int64(125), np.int64(136), np.int64(137), np.int64(156), np.int64(184)]
#      index  amount
# 124    125       3
# 135    136      10
# 136    137       4
# 155    156       2
# 183    184       4
# Indices that sum to 23: [np.int64(125), np.int64(136), np.int64(156), np.int64(159)]
#      index  amount
# 124    125       3
# 135    136      10
# 155    156       2
# 158    159       8
# Indices that sum to 23: [np.int64(125), np.int64(137), np.int64(151), np.int64(156), np.int64(171)]
#      index  amount
# 124    125       3
# 136    137       4
# 150    151       7
# 155    156       2
# 170    171       7
# Indices that sum to 23: [np.int64(125), np.int64(137), np.int64(151), np.int64(199)]
#      index  amount
# 124    125       3
# 136    137       4
# 150    151       7
# 198    199       9
# Indices that sum to 23: [np.int64(125), np.int64(137), np.int64(156), np.int64(176)]
#      index  amount
# 124    125       3
# 136    137       4
# 155    156       2
# 175    176      14
# Indices that sum to 23: [np.int64(125), np.int64(137), np.int64(171), np.int64(199)]
#      index  amount
# 124    125       3
# 136    137       4
# 170    171       7
# 198    199       9
# Indices that sum to 23: [np.int64(125), np.int64(137), np.int64(184), np.int64(196)]
#      index  amount
# 124    125       3
# 136    137       4
# 183    184       4
# 195    196      12
# Indices that sum to 23: [np.int64(125), np.int64(146), np.int64(151), np.int64(156)]
#      index  amount
# 124    125       3
# 145    146      11
# 150    151       7
# 155    156       2
# Indices that sum to 23: [np.int64(125), np.int64(146), np.int64(156), np.int64(171)]
#      index  amount
# 124    125       3
# 145    146      11
# 155    156       2
# 170    171       7
# Indices that sum to 23: [np.int64(125), np.int64(146), np.int64(199)]
#      index  amount
# 124    125       3
# 145    146      11
# 198    199       9
# Indices that sum to 23: [np.int64(125), np.int64(151), np.int64(155)]
#      index  amount
# 124    125       3
# 150    151       7
# 154    155      13
# Indices that sum to 23: [np.int64(125), np.int64(151), np.int64(156), np.int64(171), np.int64(184)]
#      index  amount
# 124    125       3
# 150    151       7
# 155    156       2
# 170    171       7
# 183    184       4
# Indices that sum to 23: [np.int64(125), np.int64(151), np.int64(157)]
#      index  amount
# 124    125       3
# 150    151       7
# 156    157      13
# Indices that sum to 23: [np.int64(125), np.int64(151), np.int64(184), np.int64(199)]
#      index  amount
# 124    125       3
# 150    151       7
# 183    184       4
# 198    199       9
# Indices that sum to 23: [np.int64(125), np.int64(155), np.int64(171)]
#      index  amount
# 124    125       3
# 154    155      13
# 170    171       7
# Indices that sum to 23: [np.int64(125), np.int64(156), np.int64(176), np.int64(184)]
#      index  amount
# 124    125       3
# 155    156       2
# 175    176      14
# 183    184       4
# Indices that sum to 23: [np.int64(125), np.int64(156), np.int64(185)]
#      index  amount
# 124    125       3
# 155    156       2
# 184    185      18
# Indices that sum to 23: [np.int64(125), np.int64(157), np.int64(171)]
#      index  amount
# 124    125       3
# 156    157      13
# 170    171       7
# Indices that sum to 23: [np.int64(125), np.int64(159), np.int64(196)]
#      index  amount
# 124    125       3
# 158    159       8
# 195    196      12
# Indices that sum to 23: [np.int64(125), np.int64(171), np.int64(184), np.int64(199)]
#      index  amount
# 124    125       3
# 170    171       7
# 183    184       4
# 198    199       9
# Indices that sum to 23: [np.int64(126), np.int64(129), np.int64(156)]
#      index  amount
# 125    126       9
# 128    129      12
# 155    156       2
# Indices that sum to 23: [np.int64(126), np.int64(130)]
#      index  amount
# 125    126       9
# 129    130      14
# Indices that sum to 23: [np.int64(126), np.int64(136), np.int64(137)]
#      index  amount
# 125    126       9
# 135    136      10
# 136    137       4
# Indices that sum to 23: [np.int64(126), np.int64(136), np.int64(184)]
#      index  amount
# 125    126       9
# 135    136      10
# 183    184       4
# Indices that sum to 23: [np.int64(126), np.int64(137), np.int64(156), np.int64(159)]
#      index  amount
# 125    126       9
# 136    137       4
# 155    156       2
# 158    159       8
# Indices that sum to 23: [np.int64(126), np.int64(151), np.int64(171)]
#      index  amount
# 125    126       9
# 150    151       7
# 170    171       7
# Indices that sum to 23: [np.int64(126), np.int64(156), np.int64(159), np.int64(184)]
#      index  amount
# 125    126       9
# 155    156       2
# 158    159       8
# 183    184       4
# Indices that sum to 23: [np.int64(126), np.int64(156), np.int64(196)]
#      index  amount
# 125    126       9
# 155    156       2
# 195    196      12
# Indices that sum to 23: [np.int64(126), np.int64(176)]
#      index  amount
# 125    126       9
# 175    176      14
# Indices that sum to 23: [np.int64(129), np.int64(137), np.int64(151)]
#      index  amount
# 128    129      12
# 136    137       4
# 150    151       7
# Indices that sum to 23: [np.int64(129), np.int64(137), np.int64(171)]
#      index  amount
# 128    129      12
# 136    137       4
# 170    171       7
# Indices that sum to 23: [np.int64(129), np.int64(146)]
#      index  amount
# 128    129      12
# 145    146      11
# Indices that sum to 23: [np.int64(129), np.int64(151), np.int64(184)]
#      index  amount
# 128    129      12
# 150    151       7
# 183    184       4
# Indices that sum to 23: [np.int64(129), np.int64(156), np.int64(199)]
#      index  amount
# 128    129      12
# 155    156       2
# 198    199       9
# Indices that sum to 23: [np.int64(129), np.int64(171), np.int64(184)]
#      index  amount
# 128    129      12
# 170    171       7
# 183    184       4
# Indices that sum to 23: [np.int64(130), np.int64(151), np.int64(156)]
#      index  amount
# 129    130      14
# 150    151       7
# 155    156       2
# Indices that sum to 23: [np.int64(130), np.int64(156), np.int64(171)]
#      index  amount
# 129    130      14
# 155    156       2
# 170    171       7
# Indices that sum to 23: [np.int64(130), np.int64(199)]
#      index  amount
# 129    130      14
# 198    199       9
# Indices that sum to 23: [np.int64(136), np.int64(137), np.int64(151), np.int64(156)]
#      index  amount
# 135    136      10
# 136    137       4
# 150    151       7
# 155    156       2
# Indices that sum to 23: [np.int64(136), np.int64(137), np.int64(156), np.int64(171)]
#      index  amount
# 135    136      10
# 136    137       4
# 155    156       2
# 170    171       7
# Indices that sum to 23: [np.int64(136), np.int64(137), np.int64(199)]
#      index  amount
# 135    136      10
# 136    137       4
# 198    199       9
# Indices that sum to 23: [np.int64(136), np.int64(146), np.int64(156)]
#      index  amount
# 135    136      10
# 145    146      11
# 155    156       2
# Indices that sum to 23: [np.int64(136), np.int64(151), np.int64(156), np.int64(184)]
#      index  amount
# 135    136      10
# 150    151       7
# 155    156       2
# 183    184       4
# Indices that sum to 23: [np.int64(136), np.int64(155)]
#      index  amount
# 135    136      10
# 154    155      13
# Indices that sum to 23: [np.int64(136), np.int64(156), np.int64(171), np.int64(184)]
#      index  amount
# 135    136      10
# 155    156       2
# 170    171       7
# 183    184       4
# Indices that sum to 23: [np.int64(136), np.int64(157)]
#      index  amount
# 135    136      10
# 156    157      13
# Indices that sum to 23: [np.int64(136), np.int64(184), np.int64(199)]
#      index  amount
# 135    136      10
# 183    184       4
# 198    199       9
# Indices that sum to 23: [np.int64(137), np.int64(139), np.int64(156)]
#      index  amount
# 136    137       4
# 138    139      17
# 155    156       2
# Indices that sum to 23: [np.int64(137), np.int64(146), np.int64(159)]
#      index  amount
# 136    137       4
# 145    146      11
# 158    159       8
# Indices that sum to 23: [np.int64(137), np.int64(151), np.int64(159), np.int64(184)]
#      index  amount
# 136    137       4
# 150    151       7
# 158    159       8
# 183    184       4
# Indices that sum to 23: [np.int64(137), np.int64(151), np.int64(196)]
#      index  amount
# 136    137       4
# 150    151       7
# 195    196      12
# Indices that sum to 23: [np.int64(137), np.int64(155), np.int64(156), np.int64(184)]
#      index  amount
# 136    137       4
# 154    155      13
# 155    156       2
# 183    184       4
# Indices that sum to 23: [np.int64(137), np.int64(156), np.int64(157), np.int64(184)]
#      index  amount
# 136    137       4
# 155    156       2
# 156    157      13
# 183    184       4
# Indices that sum to 23: [np.int64(137), np.int64(156), np.int64(159), np.int64(199)]
#      index  amount
# 136    137       4
# 155    156       2
# 158    159       8
# 198    199       9
# Indices that sum to 23: [np.int64(137), np.int64(156), np.int64(162)]
#      index  amount
# 136    137       4
# 155    156       2
# 161    162      17
# Indices that sum to 23: [np.int64(137), np.int64(156), np.int64(180)]
#      index  amount
# 136    137       4
# 155    156       2
# 179    180      17
# Indices that sum to 23: [np.int64(137), np.int64(159), np.int64(171), np.int64(184)]
#      index  amount
# 136    137       4
# 158    159       8
# 170    171       7
# 183    184       4
# Indices that sum to 23: [np.int64(137), np.int64(171), np.int64(196)]
#      index  amount
# 136    137       4
# 170    171       7
# 195    196      12
# Indices that sum to 23: [np.int64(139), np.int64(156), np.int64(184)]
#      index  amount
# 138    139      17
# 155    156       2
# 183    184       4
# Indices that sum to 23: [np.int64(146), np.int64(159), np.int64(184)]
#      index  amount
# 145    146      11
# 158    159       8
# 183    184       4
# Indices that sum to 23: [np.int64(146), np.int64(196)]
#      index  amount
# 145    146      11
# 195    196      12
# Indices that sum to 23: [np.int64(151), np.int64(156), np.int64(176)]
#      index  amount
# 150    151       7
# 155    156       2
# 175    176      14
# Indices that sum to 23: [np.int64(151), np.int64(171), np.int64(199)]
#      index  amount
# 150    151       7
# 170    171       7
# 198    199       9
# Indices that sum to 23: [np.int64(151), np.int64(184), np.int64(196)]
#      index  amount
# 150    151       7
# 183    184       4
# 195    196      12
# Indices that sum to 23: [np.int64(155), np.int64(156), np.int64(159)]
#      index  amount
# 154    155      13
# 155    156       2
# 158    159       8
# Indices that sum to 23: [np.int64(156), np.int64(157), np.int64(159)]
#      index  amount
# 155    156       2
# 156    157      13
# 158    159       8
# Indices that sum to 23: [np.int64(156), np.int64(159), np.int64(184), np.int64(199)]
#      index  amount
# 155    156       2
# 158    159       8
# 183    184       4
# 198    199       9
# Indices that sum to 23: [np.int64(156), np.int64(162), np.int64(184)]
#      index  amount
# 155    156       2
# 161    162      17
# 183    184       4
# Indices that sum to 23: [np.int64(156), np.int64(171), np.int64(176)]
#      index  amount
# 155    156       2
# 170    171       7
# 175    176      14
# Indices that sum to 23: [np.int64(156), np.int64(180), np.int64(184)]
#      index  amount
# 155    156       2
# 179    180      17
# 183    184       4
# Indices that sum to 23: [np.int64(156), np.int64(189)]
#      index  amount
# 155    156       2
# 188    189      21
# Indices that sum to 23: [np.int64(156), np.int64(196), np.int64(199)]
#      index  amount
# 155    156       2
# 195    196      12
# 198    199       9
# Indices that sum to 23: [np.int64(171), np.int64(184), np.int64(196)]
#      index  amount
# 170    171       7
# 183    184       4
# 195    196      12
# Indices that sum to 23: [np.int64(176), np.int64(199)]
#      index  amount
# 175    176      14
# 198    199       9

# %%
df_used = pd.DataFrame(df_new[1].copy())

# %%
df_used
# Out:
#     index  amount
# 1       2      16
# 8       9       1
# 47     48       6
